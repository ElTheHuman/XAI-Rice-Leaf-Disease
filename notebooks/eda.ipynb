# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# # Set directory path

# %%
import os

# %%
train_aug_dir = '../data/Rice_Leaf_AUG/Rice_Leaf_AUG'
class_list = os.listdir(train_aug_dir)

# %% [markdown]
# # Number of classes

# %%
print(f'Number of classes: {len(class_list)}')
# Out:
# Number of classes: 9

# %% [markdown]
# # Number of records in every class

# %%
total_records = 0
num_records = []

for classes in class_list:
    subdir = os.path.join(train_aug_dir, classes)
    curr_num_records = len(os.listdir(subdir))
    print(f'Number of records in class {classes}: {curr_num_records}')
    num_records.append(curr_num_records)
    total_records += curr_num_records
# Out:
# Number of records in class Bacterial Leaf Blight: 1197
# Number of records in class Brown Spot: 1546
# Number of records in class Healthy Rice Leaf: 1085
# Number of records in class Leaf Blast: 1748
# Number of records in class Leaf scald: 1332
# Number of records in class Narrow Brown Leaf Spot: 954
# Number of records in class Neck_Blast: 1000
# Number of records in class Rice Hispa: 1299
# Number of records in class Sheath Blight: 1629

# %% [markdown]
# # Total records

# %%
print(f'Total records for all classes: {total_records}')
# Out:
# Total records for all classes: 11790

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
# plt.rcParams.update({'font.size': 6.5})
# plt.pie(num_records, labels=class_list, autopct='%1.2f%%')
# plt.bar(class_list, num_records)
plt.barh(class_list, width=num_records)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# The classes records are almost evenly distributed based on the pie chart
